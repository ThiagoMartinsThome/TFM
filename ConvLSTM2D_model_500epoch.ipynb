# %% [markdown]
# <a href="https://colab.research.google.com/github/ThiagoMartinsThome/TFM/blob/master/ConvLSTM2D_model_500epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import pandas as pd
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout, Input
from tensorflow.keras.layers import TimeDistributed, RepeatVector
from tensorflow.keras.layers import Activation, MaxPool3D
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import ConvLSTM2D
from tensorflow.keras.layers import BatchNormalization
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, QuantileTransformer, PowerTransformer, LabelEncoder
from sklearn.metrics import mean_squared_error , mean_absolute_error, r2_score
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectPercentile, f_regression
from sklearn.model_selection import train_test_split
import joblib
rcParams['figure.figsize'] = 16, 8
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Load and prepare the data

# %% [markdown]
# #### Load the data

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/TFM/tradebot_tfm/data_20day_chg_target.zip', parse_dates=['date'])
data.drop('long_name', axis=1, inplace=True)
data.dropna(inplace=True, axis=0)
data.sort_values(by=['ticker', 'date'], ascending=True, inplace=True)
data.set_index('date', inplace=True)
print('Null values: ', data.isnull().sum().sum())

data.head()
# Out:
# Null values:  0
#            ticker  ...                                    industry
# date               ...
# 1993-11-11   AAPL  ...  Technology Hardware, Storage & Peripherals
# 1993-11-12   AAPL  ...  Technology Hardware, Storage & Peripherals
# 1993-11-15   AAPL  ...  Technology Hardware, Storage & Peripherals
# 1993-11-16   AAPL  ...  Technology Hardware, Storage & Peripherals
# 1993-11-17   AAPL  ...  Technology Hardware, Storage & Peripherals
#
# [5 rows x 77 columns]

# %% [markdown]
# #### Define features and targets

# %%
# Define features and target
X, y = data.drop(['short_result'], axis=1), data['short_result']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, shuffle=False)

# %% [markdown]
# #### Build a Pipeline

# %%
#Pipeline

#Column transformation
# determine categorical and numerical features
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X_train.select_dtypes(include=['object', 'bool']).columns

# Column preparation
transformer = [
               ('scaler', StandardScaler(), numerical_cols),
               ('onehot', OneHotEncoder(sparse=False), categorical_cols)]
col_transform = ColumnTransformer(transformers=transformer)

pipeline_x = Pipeline(steps=[('prep', col_transform),
                             ('pca', PCA(n_components=30, random_state=1))
                             ])
pipeline_y =  Pipeline(steps=[
                              ('scaler', StandardScaler())
                              ])

pipeline_x.fit(X, y)
pipeline_y.fit(y.values.reshape(-1, 1))

joblib.dump(pipeline_x, 'pipeline_x.pkl', compress=1)
joblib.dump(pipeline_y, 'pipeline_y.pkl', compress=1)

with open('pipeline_x.pkl',  'rb') as f_x:
    pipeline_x_loaded = joblib.load(f_x)

with open('pipeline_y.pkl',  'rb') as f_y:
    pipeline_y_loaded = joblib.load(f_y)

X_train_scaled, y_train_scaled = pipeline_x_loaded.transform(X_train), pipeline_y_loaded.transform(y_train.values.reshape((-1,1)))
X_val_scaled, y_val_scaled = pipeline_x_loaded.transform(X_val), pipeline_y_loaded.transform(y_val.values.reshape((-1,1)))

X_train_scaled.astype('float32')
y_train_scaled.astype('float32')

X_val_scaled.astype('float32')
y_val_scaled.astype('float32')

print('Min value: ', round(X_train_scaled.min(),2))
print('Max value: ', round(X_train_scaled.max(),2))
plt.hist(X_train_scaled);
print(X_train_scaled.shape)
# Out:
# Min value:  -81.76
# Max value:  146.46
# (160729, 30)

# %%
print('Min value: ', round(y_train_scaled.min(),2))
print('Max value: ', round(y_train_scaled.max(),2))
plt.hist(y_train_scaled, bins=100);
# Out:
# Min value:  -15.26
# Max value:  15.47

# %% [markdown]
# #### Split the data into sequences to be used for the model

# %%
# Split into sequences
def split_sequences(sequences, n_steps_split):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_split
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix - 1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


# choose a number of time steps
n_steps_split = 30
# Concat features and target
train_dataset = np.hstack((X_train_scaled, y_train_scaled))
val_dataset = np.hstack((X_val_scaled, y_val_scaled))
# convert into input/output
X_train_split, y_train_split = split_sequences(train_dataset, n_steps_split)
y_train_split = np.reshape(y_train_split, (-1, 1))
X_val_split, y_val_split = split_sequences(val_dataset, n_steps_split)
y_val_split = np.reshape(y_val_split, (-1, 1))

# the dataset knows the number of features, e.g. 2
n_features = X_train_split.shape[2]
n_seq = 5
n_steps = 6
#We can define the ConvLSTM as a single layer in terms of the number of filters
#and a two-dimensional kernel size in terms of (rows, columns).
#As we are working with a one-dimensional series, the number of rows is always
#fixed to 1 in the kernel.
rows = 1

X_train_split = X_train_split.reshape((X_train_split.shape[0], n_seq, rows, n_steps, n_features))
X_val_split = X_val_split.reshape((X_val_split.shape[0], n_seq, rows, n_steps, n_features))

print(X_train_split.shape, y_train_split.shape)
# Out:
# (160700, 5, 1, 6, 30) (160700, 1)

# %% [markdown]
# ## Build the model

# %%
# define model
model = Sequential()
model.add(BatchNormalization(input_shape=(n_seq, rows, n_steps, n_features)))
model.add(ConvLSTM2D(filters=90,
                     kernel_size=(5, 6),
                     padding='same',
                     return_sequences=True,
                     dropout=0.2))
model.add(BatchNormalization())
model.add(Flatten())
model.add(RepeatVector(1))
model.add(BatchNormalization())
model.add(Bidirectional(LSTM(50, return_sequences=True)))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(TimeDistributed(Dense(1)))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Model path
checkpoint_path = 'ConvLSTM2D_model.h5'

## Callbacks:
# Create a callback that saves the model's weights
cp_callback = ModelCheckpoint(filepath=checkpoint_path,
                              save_weights_only=False,
                              verbose=1, save_best_only=True,
                              monitor='loss')
# Create a callback that prevents the overfitting
early_stopping = EarlyStopping(monitor='loss', mode='auto', verbose=2,
                               patience=10)
# Create a callback to increase the learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=1, min_lr=1e-5, mode='min')

# fit model
history = model.fit(X_train_split, y_train_split, epochs=500, batch_size=1024,
                    callbacks=[cp_callback, early_stopping, reduce_lr, TerminateOnNaN()],
                    validation_data=(X_val_split, y_val_split), shuffle=True)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# Out:
# Epoch 1/500
#   2/157 [..............................] - ETA: 10s - loss: 1.2110 - mae: 0.7166WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0490s vs `on_train_batch_end` time: 0.0877s). Check your callbacks.
# 157/157 [==============================] - ETA: 0s - loss: 1.0305 - mae: 0.6920
# Epoch 00001: loss improved from inf to 1.03045, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 25s 157ms/step - loss: 1.0305 - mae: 0.6920 - val_loss: 1.1853 - val_mae: 0.7231
# Epoch 2/500
# 157/157 [==============================] - ETA: 0s - loss: 0.9896 - mae: 0.6810
# Epoch 00002: loss improved from 1.03045 to 0.98959, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.9896 - mae: 0.6810 - val_loss: 1.1965 - val_mae: 0.7293
# Epoch 3/500
# 157/157 [==============================] - ETA: 0s - loss: 0.9056 - mae: 0.6583
# Epoch 00003: loss improved from 0.98959 to 0.90561, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.9056 - mae: 0.6583 - val_loss: 1.2326 - val_mae: 0.7433
# Epoch 4/500
# 157/157 [==============================] - ETA: 0s - loss: 0.8420 - mae: 0.6413
# Epoch 00004: loss improved from 0.90561 to 0.84198, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.8420 - mae: 0.6413 - val_loss: 1.2755 - val_mae: 0.7584
# Epoch 5/500
# 157/157 [==============================] - ETA: 0s - loss: 0.8222 - mae: 0.6362
# Epoch 00005: loss improved from 0.84198 to 0.82221, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.8222 - mae: 0.6362 - val_loss: 1.2906 - val_mae: 0.7638
# Epoch 6/500
# 157/157 [==============================] - ETA: 0s - loss: 0.8163 - mae: 0.6337
# Epoch 00006: loss improved from 0.82221 to 0.81632, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.8163 - mae: 0.6337 - val_loss: 1.2994 - val_mae: 0.7667
# Epoch 7/500
# 157/157 [==============================] - ETA: 0s - loss: 0.8127 - mae: 0.6340
# Epoch 00007: loss improved from 0.81632 to 0.81275, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.8127 - mae: 0.6340 - val_loss: 1.3018 - val_mae: 0.7675
# Epoch 8/500
# 157/157 [==============================] - ETA: 0s - loss: 0.8094 - mae: 0.6328
# Epoch 00008: loss improved from 0.81275 to 0.80937, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.8094 - mae: 0.6328 - val_loss: 1.3061 - val_mae: 0.7688
# Epoch 9/500
# 157/157 [==============================] - ETA: 0s - loss: 0.8018 - mae: 0.6308
# Epoch 00009: loss improved from 0.80937 to 0.80184, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.8018 - mae: 0.6308 - val_loss: 1.3099 - val_mae: 0.7700
# Epoch 10/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7991 - mae: 0.6295
# Epoch 00010: loss improved from 0.80184 to 0.79912, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7991 - mae: 0.6295 - val_loss: 1.3139 - val_mae: 0.7711
# Epoch 11/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7960 - mae: 0.6292
# Epoch 00011: loss improved from 0.79912 to 0.79598, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7960 - mae: 0.6292 - val_loss: 1.3167 - val_mae: 0.7724
# Epoch 12/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7893 - mae: 0.6275
# Epoch 00012: loss improved from 0.79598 to 0.78934, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7893 - mae: 0.6275 - val_loss: 1.3202 - val_mae: 0.7735
# Epoch 13/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7858 - mae: 0.6263
# Epoch 00013: loss improved from 0.78934 to 0.78577, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7858 - mae: 0.6263 - val_loss: 1.3238 - val_mae: 0.7747
# Epoch 14/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7847 - mae: 0.6253
# Epoch 00014: loss improved from 0.78577 to 0.78472, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7847 - mae: 0.6253 - val_loss: 1.3265 - val_mae: 0.7756
# Epoch 15/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7806 - mae: 0.6246
# Epoch 00015: loss improved from 0.78472 to 0.78060, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7806 - mae: 0.6246 - val_loss: 1.3296 - val_mae: 0.7763
# Epoch 16/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7747 - mae: 0.6224
# Epoch 00016: loss improved from 0.78060 to 0.77474, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7747 - mae: 0.6224 - val_loss: 1.3324 - val_mae: 0.7771
# Epoch 17/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7745 - mae: 0.6227
# Epoch 00017: loss improved from 0.77474 to 0.77452, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7745 - mae: 0.6227 - val_loss: 1.3354 - val_mae: 0.7778
# Epoch 18/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7674 - mae: 0.6212
# Epoch 00018: loss improved from 0.77452 to 0.76742, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7674 - mae: 0.6212 - val_loss: 1.3357 - val_mae: 0.7780
# Epoch 19/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7642 - mae: 0.6206
# Epoch 00019: loss improved from 0.76742 to 0.76415, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7642 - mae: 0.6206 - val_loss: 1.3403 - val_mae: 0.7791
# Epoch 20/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7606 - mae: 0.6197
# Epoch 00020: loss improved from 0.76415 to 0.76064, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7606 - mae: 0.6197 - val_loss: 1.3408 - val_mae: 0.7794
# Epoch 21/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7585 - mae: 0.6186
# Epoch 00021: loss improved from 0.76064 to 0.75853, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7585 - mae: 0.6186 - val_loss: 1.3473 - val_mae: 0.7810
# Epoch 22/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7536 - mae: 0.6176
# Epoch 00022: loss improved from 0.75853 to 0.75362, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7536 - mae: 0.6176 - val_loss: 1.3485 - val_mae: 0.7816
# Epoch 23/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7510 - mae: 0.6172
# Epoch 00023: loss improved from 0.75362 to 0.75103, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7510 - mae: 0.6172 - val_loss: 1.3513 - val_mae: 0.7823
# Epoch 24/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7469 - mae: 0.6154
# Epoch 00024: loss improved from 0.75103 to 0.74688, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7469 - mae: 0.6154 - val_loss: 1.3540 - val_mae: 0.7829
# Epoch 25/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7449 - mae: 0.6159
# Epoch 00025: loss improved from 0.74688 to 0.74495, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7449 - mae: 0.6159 - val_loss: 1.3564 - val_mae: 0.7833
# Epoch 26/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7415 - mae: 0.6139
# Epoch 00026: loss improved from 0.74495 to 0.74152, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7415 - mae: 0.6139 - val_loss: 1.3566 - val_mae: 0.7838
# Epoch 27/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7350 - mae: 0.6118
# Epoch 00027: loss improved from 0.74152 to 0.73496, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7350 - mae: 0.6118 - val_loss: 1.3603 - val_mae: 0.7846
# Epoch 28/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7334 - mae: 0.6116
# Epoch 00028: loss improved from 0.73496 to 0.73339, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7334 - mae: 0.6116 - val_loss: 1.3603 - val_mae: 0.7848
# Epoch 29/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7296 - mae: 0.6104
# Epoch 00029: loss improved from 0.73339 to 0.72962, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7296 - mae: 0.6104 - val_loss: 1.3607 - val_mae: 0.7851
# Epoch 30/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7247 - mae: 0.6097
# Epoch 00030: loss improved from 0.72962 to 0.72472, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7247 - mae: 0.6097 - val_loss: 1.3619 - val_mae: 0.7855
# Epoch 31/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7261 - mae: 0.6101
# Epoch 00031: loss did not improve from 0.72472
# 157/157 [==============================] - 23s 147ms/step - loss: 0.7261 - mae: 0.6101 - val_loss: 1.3644 - val_mae: 0.7861
# Epoch 32/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7205 - mae: 0.6090
# Epoch 00032: loss improved from 0.72472 to 0.72046, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7205 - mae: 0.6090 - val_loss: 1.3655 - val_mae: 0.7861
# Epoch 33/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7188 - mae: 0.6076
# Epoch 00033: loss improved from 0.72046 to 0.71885, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7188 - mae: 0.6076 - val_loss: 1.3661 - val_mae: 0.7863
# Epoch 34/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7169 - mae: 0.6065
# Epoch 00034: loss improved from 0.71885 to 0.71687, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7169 - mae: 0.6065 - val_loss: 1.3684 - val_mae: 0.7871
# Epoch 35/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7148 - mae: 0.6067
# Epoch 00035: loss improved from 0.71687 to 0.71484, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7148 - mae: 0.6067 - val_loss: 1.3727 - val_mae: 0.7880
# Epoch 36/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7092 - mae: 0.6040
# Epoch 00036: loss improved from 0.71484 to 0.70916, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7092 - mae: 0.6040 - val_loss: 1.3729 - val_mae: 0.7883
# Epoch 37/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7074 - mae: 0.6035
# Epoch 00037: loss improved from 0.70916 to 0.70735, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7074 - mae: 0.6035 - val_loss: 1.3732 - val_mae: 0.7882
# Epoch 38/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7048 - mae: 0.6032
# Epoch 00038: loss improved from 0.70735 to 0.70483, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7048 - mae: 0.6032 - val_loss: 1.3740 - val_mae: 0.7883
# Epoch 39/500
# 157/157 [==============================] - ETA: 0s - loss: 0.7015 - mae: 0.6018
# Epoch 00039: loss improved from 0.70483 to 0.70153, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.7015 - mae: 0.6018 - val_loss: 1.3791 - val_mae: 0.7898
# Epoch 40/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6991 - mae: 0.6017
# Epoch 00040: loss improved from 0.70153 to 0.69913, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6991 - mae: 0.6017 - val_loss: 1.3778 - val_mae: 0.7895
# Epoch 41/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6986 - mae: 0.6022
# Epoch 00041: loss improved from 0.69913 to 0.69856, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6986 - mae: 0.6022 - val_loss: 1.3801 - val_mae: 0.7900
# Epoch 42/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6927 - mae: 0.5992
# Epoch 00042: loss improved from 0.69856 to 0.69270, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6927 - mae: 0.5992 - val_loss: 1.3805 - val_mae: 0.7898
# Epoch 43/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6912 - mae: 0.5986
# Epoch 00043: loss improved from 0.69270 to 0.69119, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 149ms/step - loss: 0.6912 - mae: 0.5986 - val_loss: 1.3790 - val_mae: 0.7896
# Epoch 44/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6872 - mae: 0.5977
# Epoch 00044: loss improved from 0.69119 to 0.68724, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6872 - mae: 0.5977 - val_loss: 1.3831 - val_mae: 0.7906
# Epoch 45/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6858 - mae: 0.5971
# Epoch 00045: loss improved from 0.68724 to 0.68578, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6858 - mae: 0.5971 - val_loss: 1.3804 - val_mae: 0.7896
# Epoch 46/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6800 - mae: 0.5961
# Epoch 00046: loss improved from 0.68578 to 0.68000, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6800 - mae: 0.5961 - val_loss: 1.3810 - val_mae: 0.7901
# Epoch 47/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6784 - mae: 0.5955
# Epoch 00047: loss improved from 0.68000 to 0.67841, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6784 - mae: 0.5955 - val_loss: 1.3833 - val_mae: 0.7905
# Epoch 48/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6780 - mae: 0.5945
# Epoch 00048: loss improved from 0.67841 to 0.67804, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6780 - mae: 0.5945 - val_loss: 1.3866 - val_mae: 0.7911
# Epoch 49/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6746 - mae: 0.5930
# Epoch 00049: loss improved from 0.67804 to 0.67459, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6746 - mae: 0.5930 - val_loss: 1.3893 - val_mae: 0.7914
# Epoch 50/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6718 - mae: 0.5925
# Epoch 00050: loss improved from 0.67459 to 0.67177, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6718 - mae: 0.5925 - val_loss: 1.3891 - val_mae: 0.7918
# Epoch 51/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6708 - mae: 0.5929
# Epoch 00051: loss improved from 0.67177 to 0.67079, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6708 - mae: 0.5929 - val_loss: 1.3906 - val_mae: 0.7919
# Epoch 52/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6665 - mae: 0.5912
# Epoch 00052: loss improved from 0.67079 to 0.66654, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6665 - mae: 0.5912 - val_loss: 1.3911 - val_mae: 0.7922
# Epoch 53/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6662 - mae: 0.5918
# Epoch 00053: loss improved from 0.66654 to 0.66615, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6662 - mae: 0.5918 - val_loss: 1.3928 - val_mae: 0.7928
# Epoch 54/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6658 - mae: 0.5903
# Epoch 00054: loss improved from 0.66615 to 0.66577, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6658 - mae: 0.5903 - val_loss: 1.3921 - val_mae: 0.7925
# Epoch 55/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6622 - mae: 0.5905
# Epoch 00055: loss improved from 0.66577 to 0.66220, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6622 - mae: 0.5905 - val_loss: 1.3928 - val_mae: 0.7928
# Epoch 56/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6607 - mae: 0.5893
# Epoch 00056: loss improved from 0.66220 to 0.66068, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6607 - mae: 0.5893 - val_loss: 1.3932 - val_mae: 0.7926
# Epoch 57/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6567 - mae: 0.5878
# Epoch 00057: loss improved from 0.66068 to 0.65673, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6567 - mae: 0.5878 - val_loss: 1.3944 - val_mae: 0.7928
# Epoch 58/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6532 - mae: 0.5870
# Epoch 00058: loss improved from 0.65673 to 0.65320, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6532 - mae: 0.5870 - val_loss: 1.3943 - val_mae: 0.7927
# Epoch 59/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6522 - mae: 0.5862
# Epoch 00059: loss improved from 0.65320 to 0.65215, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6522 - mae: 0.5862 - val_loss: 1.3941 - val_mae: 0.7925
# Epoch 60/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6515 - mae: 0.5863
# Epoch 00060: loss improved from 0.65215 to 0.65146, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6515 - mae: 0.5863 - val_loss: 1.3967 - val_mae: 0.7933
# Epoch 61/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6490 - mae: 0.5860
# Epoch 00061: loss improved from 0.65146 to 0.64901, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6490 - mae: 0.5860 - val_loss: 1.3980 - val_mae: 0.7933
# Epoch 62/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6431 - mae: 0.5837
# Epoch 00062: loss improved from 0.64901 to 0.64306, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6431 - mae: 0.5837 - val_loss: 1.3979 - val_mae: 0.7934
# Epoch 63/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6408 - mae: 0.5824
# Epoch 00063: loss improved from 0.64306 to 0.64079, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6408 - mae: 0.5824 - val_loss: 1.3964 - val_mae: 0.7928
# Epoch 64/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6407 - mae: 0.5825
# Epoch 00064: loss improved from 0.64079 to 0.64074, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6407 - mae: 0.5825 - val_loss: 1.3970 - val_mae: 0.7931
# Epoch 65/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6430 - mae: 0.5833
# Epoch 00065: loss did not improve from 0.64074
# 157/157 [==============================] - 23s 147ms/step - loss: 0.6430 - mae: 0.5833 - val_loss: 1.3987 - val_mae: 0.7931
# Epoch 66/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6354 - mae: 0.5806
# Epoch 00066: loss improved from 0.64074 to 0.63540, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6354 - mae: 0.5806 - val_loss: 1.3961 - val_mae: 0.7928
# Epoch 67/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6328 - mae: 0.5804
# Epoch 00067: loss improved from 0.63540 to 0.63282, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6328 - mae: 0.5804 - val_loss: 1.3971 - val_mae: 0.7931
# Epoch 68/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6306 - mae: 0.5786
# Epoch 00068: loss improved from 0.63282 to 0.63064, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6306 - mae: 0.5786 - val_loss: 1.4023 - val_mae: 0.7939
# Epoch 69/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6336 - mae: 0.5804
# Epoch 00069: loss did not improve from 0.63064
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6336 - mae: 0.5804 - val_loss: 1.4013 - val_mae: 0.7935
# Epoch 70/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6291 - mae: 0.5794
# Epoch 00070: loss improved from 0.63064 to 0.62914, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6291 - mae: 0.5794 - val_loss: 1.3988 - val_mae: 0.7931
# Epoch 71/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6271 - mae: 0.5786
# Epoch 00071: loss improved from 0.62914 to 0.62706, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6271 - mae: 0.5786 - val_loss: 1.3997 - val_mae: 0.7933
# Epoch 72/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6238 - mae: 0.5766
# Epoch 00072: loss improved from 0.62706 to 0.62375, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6238 - mae: 0.5766 - val_loss: 1.4032 - val_mae: 0.7943
# Epoch 73/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6248 - mae: 0.5775
# Epoch 00073: loss did not improve from 0.62375
# 157/157 [==============================] - 23s 147ms/step - loss: 0.6248 - mae: 0.5775 - val_loss: 1.3993 - val_mae: 0.7937
# Epoch 74/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6214 - mae: 0.5756
# Epoch 00074: loss improved from 0.62375 to 0.62137, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6214 - mae: 0.5756 - val_loss: 1.4003 - val_mae: 0.7937
# Epoch 75/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6173 - mae: 0.5745
# Epoch 00075: loss improved from 0.62137 to 0.61727, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6173 - mae: 0.5745 - val_loss: 1.4025 - val_mae: 0.7943
# Epoch 76/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6163 - mae: 0.5745
# Epoch 00076: loss improved from 0.61727 to 0.61634, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6163 - mae: 0.5745 - val_loss: 1.4018 - val_mae: 0.7943
# Epoch 77/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6140 - mae: 0.5736
# Epoch 00077: loss improved from 0.61634 to 0.61396, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6140 - mae: 0.5736 - val_loss: 1.4046 - val_mae: 0.7950
# Epoch 78/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6111 - mae: 0.5722
# Epoch 00078: loss improved from 0.61396 to 0.61113, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6111 - mae: 0.5722 - val_loss: 1.4023 - val_mae: 0.7940
# Epoch 79/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6110 - mae: 0.5726
# Epoch 00079: loss improved from 0.61113 to 0.61096, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6110 - mae: 0.5726 - val_loss: 1.4038 - val_mae: 0.7947
# Epoch 80/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6088 - mae: 0.5710
# Epoch 00080: loss improved from 0.61096 to 0.60884, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6088 - mae: 0.5710 - val_loss: 1.4057 - val_mae: 0.7949
# Epoch 81/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6089 - mae: 0.5718
# Epoch 00081: loss did not improve from 0.60884
# 157/157 [==============================] - 23s 147ms/step - loss: 0.6089 - mae: 0.5718 - val_loss: 1.4060 - val_mae: 0.7948
# Epoch 82/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6052 - mae: 0.5706
# Epoch 00082: loss improved from 0.60884 to 0.60520, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.6052 - mae: 0.5706 - val_loss: 1.4053 - val_mae: 0.7947
# Epoch 83/500
# 157/157 [==============================] - ETA: 0s - loss: 0.6053 - mae: 0.5699
# Epoch 00083: loss did not improve from 0.60520
# 157/157 [==============================] - 23s 147ms/step - loss: 0.6053 - mae: 0.5699 - val_loss: 1.4048 - val_mae: 0.7946
# Epoch 84/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5979 - mae: 0.5668
# Epoch 00084: loss improved from 0.60520 to 0.59790, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5979 - mae: 0.5668 - val_loss: 1.4067 - val_mae: 0.7945
# Epoch 85/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5992 - mae: 0.5685
# Epoch 00085: loss did not improve from 0.59790
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5992 - mae: 0.5685 - val_loss: 1.4088 - val_mae: 0.7952
# Epoch 86/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5986 - mae: 0.5688
# Epoch 00086: loss did not improve from 0.59790
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5986 - mae: 0.5688 - val_loss: 1.4098 - val_mae: 0.7953
# Epoch 87/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5963 - mae: 0.5664
# Epoch 00087: loss improved from 0.59790 to 0.59634, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5963 - mae: 0.5664 - val_loss: 1.4103 - val_mae: 0.7954
# Epoch 88/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5934 - mae: 0.5660
# Epoch 00088: loss improved from 0.59634 to 0.59343, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5934 - mae: 0.5660 - val_loss: 1.4097 - val_mae: 0.7950
# Epoch 89/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5953 - mae: 0.5669
# Epoch 00089: loss did not improve from 0.59343
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5953 - mae: 0.5669 - val_loss: 1.4073 - val_mae: 0.7947
# Epoch 90/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5918 - mae: 0.5660
# Epoch 00090: loss improved from 0.59343 to 0.59178, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5918 - mae: 0.5660 - val_loss: 1.4121 - val_mae: 0.7954
# Epoch 91/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5895 - mae: 0.5641
# Epoch 00091: loss improved from 0.59178 to 0.58947, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5895 - mae: 0.5641 - val_loss: 1.4119 - val_mae: 0.7949
# Epoch 92/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5911 - mae: 0.5644
# Epoch 00092: loss did not improve from 0.58947
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5911 - mae: 0.5644 - val_loss: 1.4138 - val_mae: 0.7958
# Epoch 93/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5862 - mae: 0.5629
# Epoch 00093: loss improved from 0.58947 to 0.58616, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5862 - mae: 0.5629 - val_loss: 1.4112 - val_mae: 0.7952
# Epoch 94/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5810 - mae: 0.5613
# Epoch 00094: loss improved from 0.58616 to 0.58105, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5810 - mae: 0.5613 - val_loss: 1.4122 - val_mae: 0.7960
# Epoch 95/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5842 - mae: 0.5622
# Epoch 00095: loss did not improve from 0.58105
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5842 - mae: 0.5622 - val_loss: 1.4117 - val_mae: 0.7957
# Epoch 96/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5813 - mae: 0.5611
# Epoch 00096: loss did not improve from 0.58105
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5813 - mae: 0.5611 - val_loss: 1.4143 - val_mae: 0.7964
# Epoch 97/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5762 - mae: 0.5590
# Epoch 00097: loss improved from 0.58105 to 0.57620, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5762 - mae: 0.5590 - val_loss: 1.4170 - val_mae: 0.7965
# Epoch 98/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5764 - mae: 0.5589
# Epoch 00098: loss did not improve from 0.57620
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5764 - mae: 0.5589 - val_loss: 1.4127 - val_mae: 0.7956
# Epoch 99/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5763 - mae: 0.5594
# Epoch 00099: loss did not improve from 0.57620
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5763 - mae: 0.5594 - val_loss: 1.4111 - val_mae: 0.7951
# Epoch 100/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5742 - mae: 0.5590
# Epoch 00100: loss improved from 0.57620 to 0.57416, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5742 - mae: 0.5590 - val_loss: 1.4138 - val_mae: 0.7959
# Epoch 101/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5739 - mae: 0.5583
# Epoch 00101: loss improved from 0.57416 to 0.57389, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5739 - mae: 0.5583 - val_loss: 1.4087 - val_mae: 0.7951
# Epoch 102/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5690 - mae: 0.5563
# Epoch 00102: loss improved from 0.57389 to 0.56904, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5690 - mae: 0.5563 - val_loss: 1.4105 - val_mae: 0.7951
# Epoch 103/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5675 - mae: 0.5561
# Epoch 00103: loss improved from 0.56904 to 0.56753, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5675 - mae: 0.5561 - val_loss: 1.4107 - val_mae: 0.7957
# Epoch 104/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5675 - mae: 0.5558
# Epoch 00104: loss improved from 0.56753 to 0.56747, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5675 - mae: 0.5558 - val_loss: 1.4144 - val_mae: 0.7964
# Epoch 105/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5684 - mae: 0.5563
# Epoch 00105: loss did not improve from 0.56747
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5684 - mae: 0.5563 - val_loss: 1.4115 - val_mae: 0.7957
# Epoch 106/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5658 - mae: 0.5552
# Epoch 00106: loss improved from 0.56747 to 0.56576, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5658 - mae: 0.5552 - val_loss: 1.4166 - val_mae: 0.7967
# Epoch 107/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5608 - mae: 0.5528
# Epoch 00107: loss improved from 0.56576 to 0.56079, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5608 - mae: 0.5528 - val_loss: 1.4171 - val_mae: 0.7972
# Epoch 108/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5588 - mae: 0.5524
# Epoch 00108: loss improved from 0.56079 to 0.55879, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5588 - mae: 0.5524 - val_loss: 1.4170 - val_mae: 0.7967
# Epoch 109/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5641 - mae: 0.5545
# Epoch 00109: loss did not improve from 0.55879
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5641 - mae: 0.5545 - val_loss: 1.4172 - val_mae: 0.7967
# Epoch 110/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5577 - mae: 0.5527
# Epoch 00110: loss improved from 0.55879 to 0.55765, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5577 - mae: 0.5527 - val_loss: 1.4151 - val_mae: 0.7960
# Epoch 111/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5578 - mae: 0.5528
# Epoch 00111: loss did not improve from 0.55765
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5578 - mae: 0.5528 - val_loss: 1.4162 - val_mae: 0.7963
# Epoch 112/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5555 - mae: 0.5510
# Epoch 00112: loss improved from 0.55765 to 0.55547, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5555 - mae: 0.5510 - val_loss: 1.4158 - val_mae: 0.7961
# Epoch 113/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5558 - mae: 0.5509
# Epoch 00113: loss did not improve from 0.55547
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5558 - mae: 0.5509 - val_loss: 1.4146 - val_mae: 0.7962
# Epoch 114/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5524 - mae: 0.5501
# Epoch 00114: loss improved from 0.55547 to 0.55240, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5524 - mae: 0.5501 - val_loss: 1.4167 - val_mae: 0.7966
# Epoch 115/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5523 - mae: 0.5504
# Epoch 00115: loss improved from 0.55240 to 0.55229, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5523 - mae: 0.5504 - val_loss: 1.4154 - val_mae: 0.7963
# Epoch 116/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5511 - mae: 0.5491
# Epoch 00116: loss improved from 0.55229 to 0.55107, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5511 - mae: 0.5491 - val_loss: 1.4152 - val_mae: 0.7960
# Epoch 117/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5468 - mae: 0.5475
# Epoch 00117: loss improved from 0.55107 to 0.54679, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5468 - mae: 0.5475 - val_loss: 1.4147 - val_mae: 0.7964
# Epoch 118/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5497 - mae: 0.5482
# Epoch 00118: loss did not improve from 0.54679
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5497 - mae: 0.5482 - val_loss: 1.4166 - val_mae: 0.7965
# Epoch 119/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5488 - mae: 0.5479
# Epoch 00119: loss did not improve from 0.54679
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5488 - mae: 0.5479 - val_loss: 1.4171 - val_mae: 0.7970
# Epoch 120/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5481 - mae: 0.5484
# Epoch 00120: loss did not improve from 0.54679
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5481 - mae: 0.5484 - val_loss: 1.4136 - val_mae: 0.7963
# Epoch 121/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5447 - mae: 0.5465
# Epoch 00121: loss improved from 0.54679 to 0.54472, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5447 - mae: 0.5465 - val_loss: 1.4135 - val_mae: 0.7965
# Epoch 122/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5415 - mae: 0.5454
# Epoch 00122: loss improved from 0.54472 to 0.54152, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5415 - mae: 0.5454 - val_loss: 1.4122 - val_mae: 0.7962
# Epoch 123/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5401 - mae: 0.5444
# Epoch 00123: loss improved from 0.54152 to 0.54005, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5401 - mae: 0.5444 - val_loss: 1.4158 - val_mae: 0.7968
# Epoch 124/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5386 - mae: 0.5440
# Epoch 00124: loss improved from 0.54005 to 0.53857, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5386 - mae: 0.5440 - val_loss: 1.4148 - val_mae: 0.7966
# Epoch 125/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5412 - mae: 0.5444
# Epoch 00125: loss did not improve from 0.53857
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5412 - mae: 0.5444 - val_loss: 1.4134 - val_mae: 0.7964
# Epoch 126/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5375 - mae: 0.5428
# Epoch 00126: loss improved from 0.53857 to 0.53749, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5375 - mae: 0.5428 - val_loss: 1.4161 - val_mae: 0.7965
# Epoch 127/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5348 - mae: 0.5422
# Epoch 00127: loss improved from 0.53749 to 0.53481, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5348 - mae: 0.5422 - val_loss: 1.4186 - val_mae: 0.7974
# Epoch 128/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5356 - mae: 0.5426
# Epoch 00128: loss did not improve from 0.53481
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5356 - mae: 0.5426 - val_loss: 1.4163 - val_mae: 0.7969
# Epoch 129/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5339 - mae: 0.5419
# Epoch 00129: loss improved from 0.53481 to 0.53392, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5339 - mae: 0.5419 - val_loss: 1.4168 - val_mae: 0.7974
# Epoch 130/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5361 - mae: 0.5427
# Epoch 00130: loss did not improve from 0.53392
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5361 - mae: 0.5427 - val_loss: 1.4166 - val_mae: 0.7973
# Epoch 131/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5287 - mae: 0.5406
# Epoch 00131: loss improved from 0.53392 to 0.52873, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5287 - mae: 0.5406 - val_loss: 1.4215 - val_mae: 0.7983
# Epoch 132/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5289 - mae: 0.5402
# Epoch 00132: loss did not improve from 0.52873
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5289 - mae: 0.5402 - val_loss: 1.4174 - val_mae: 0.7974
# Epoch 133/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5281 - mae: 0.5402
# Epoch 00133: loss improved from 0.52873 to 0.52815, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5281 - mae: 0.5402 - val_loss: 1.4188 - val_mae: 0.7976
# Epoch 134/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5274 - mae: 0.5393
# Epoch 00134: loss improved from 0.52815 to 0.52740, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5274 - mae: 0.5393 - val_loss: 1.4164 - val_mae: 0.7968
# Epoch 135/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5267 - mae: 0.5394
# Epoch 00135: loss improved from 0.52740 to 0.52670, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5267 - mae: 0.5394 - val_loss: 1.4199 - val_mae: 0.7977
# Epoch 136/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5192 - mae: 0.5366
# Epoch 00136: loss improved from 0.52670 to 0.51920, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5192 - mae: 0.5366 - val_loss: 1.4162 - val_mae: 0.7967
# Epoch 137/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5229 - mae: 0.5378
# Epoch 00137: loss did not improve from 0.51920
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5229 - mae: 0.5378 - val_loss: 1.4147 - val_mae: 0.7965
# Epoch 138/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5244 - mae: 0.5385
# Epoch 00138: loss did not improve from 0.51920
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5244 - mae: 0.5385 - val_loss: 1.4139 - val_mae: 0.7965
# Epoch 139/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5236 - mae: 0.5374
# Epoch 00139: loss did not improve from 0.51920
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5236 - mae: 0.5374 - val_loss: 1.4194 - val_mae: 0.7976
# Epoch 140/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5178 - mae: 0.5353
# Epoch 00140: loss improved from 0.51920 to 0.51776, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5178 - mae: 0.5353 - val_loss: 1.4184 - val_mae: 0.7974
# Epoch 141/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5211 - mae: 0.5376
# Epoch 00141: loss did not improve from 0.51776
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5211 - mae: 0.5376 - val_loss: 1.4184 - val_mae: 0.7972
# Epoch 142/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5169 - mae: 0.5343
# Epoch 00142: loss improved from 0.51776 to 0.51694, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5169 - mae: 0.5343 - val_loss: 1.4221 - val_mae: 0.7983
# Epoch 143/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5147 - mae: 0.5334
# Epoch 00143: loss improved from 0.51694 to 0.51468, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5147 - mae: 0.5334 - val_loss: 1.4205 - val_mae: 0.7981
# Epoch 144/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5161 - mae: 0.5346
# Epoch 00144: loss did not improve from 0.51468
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5161 - mae: 0.5346 - val_loss: 1.4208 - val_mae: 0.7982
# Epoch 145/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5141 - mae: 0.5334
# Epoch 00145: loss improved from 0.51468 to 0.51409, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5141 - mae: 0.5334 - val_loss: 1.4202 - val_mae: 0.7981
# Epoch 146/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5113 - mae: 0.5327
# Epoch 00146: loss improved from 0.51409 to 0.51135, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5113 - mae: 0.5327 - val_loss: 1.4186 - val_mae: 0.7981
# Epoch 147/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5104 - mae: 0.5322
# Epoch 00147: loss improved from 0.51135 to 0.51040, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5104 - mae: 0.5322 - val_loss: 1.4193 - val_mae: 0.7982
# Epoch 148/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5096 - mae: 0.5323
# Epoch 00148: loss improved from 0.51040 to 0.50962, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5096 - mae: 0.5323 - val_loss: 1.4205 - val_mae: 0.7986
# Epoch 149/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5092 - mae: 0.5314
# Epoch 00149: loss improved from 0.50962 to 0.50916, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5092 - mae: 0.5314 - val_loss: 1.4230 - val_mae: 0.7989
# Epoch 150/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5089 - mae: 0.5323
# Epoch 00150: loss improved from 0.50916 to 0.50887, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5089 - mae: 0.5323 - val_loss: 1.4203 - val_mae: 0.7983
# Epoch 151/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5078 - mae: 0.5306
# Epoch 00151: loss improved from 0.50887 to 0.50781, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5078 - mae: 0.5306 - val_loss: 1.4163 - val_mae: 0.7974
# Epoch 152/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5051 - mae: 0.5296
# Epoch 00152: loss improved from 0.50781 to 0.50510, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5051 - mae: 0.5296 - val_loss: 1.4220 - val_mae: 0.7985
# Epoch 153/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5028 - mae: 0.5284
# Epoch 00153: loss improved from 0.50510 to 0.50281, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5028 - mae: 0.5284 - val_loss: 1.4246 - val_mae: 0.7990
# Epoch 154/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5043 - mae: 0.5302
# Epoch 00154: loss did not improve from 0.50281
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5043 - mae: 0.5302 - val_loss: 1.4217 - val_mae: 0.7981
# Epoch 155/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5032 - mae: 0.5291
# Epoch 00155: loss did not improve from 0.50281
# 157/157 [==============================] - 23s 147ms/step - loss: 0.5032 - mae: 0.5291 - val_loss: 1.4253 - val_mae: 0.7993
# Epoch 156/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5022 - mae: 0.5290
# Epoch 00156: loss improved from 0.50281 to 0.50217, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5022 - mae: 0.5290 - val_loss: 1.4244 - val_mae: 0.7991
# Epoch 157/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5010 - mae: 0.5271
# Epoch 00157: loss improved from 0.50217 to 0.50101, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5010 - mae: 0.5271 - val_loss: 1.4270 - val_mae: 0.7994
# Epoch 158/500
# 157/157 [==============================] - ETA: 0s - loss: 0.5004 - mae: 0.5279
# Epoch 00158: loss improved from 0.50101 to 0.50042, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.5004 - mae: 0.5279 - val_loss: 1.4259 - val_mae: 0.7994
# Epoch 159/500
# 157/157 [==============================] - ETA: 0s - loss: 0.4952 - mae: 0.5264
# Epoch 00159: loss improved from 0.50042 to 0.49518, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.4952 - mae: 0.5264 - val_loss: 1.4264 - val_mae: 0.7993
# Epoch 160/500
# 157/157 [==============================] - ETA: 0s - loss: 0.4989 - mae: 0.5260
# Epoch 00160: loss did not improve from 0.49518
# 157/157 [==============================] - 23s 147ms/step - loss: 0.4989 - mae: 0.5260 - val_loss: 1.4247 - val_mae: 0.7992
# Epoch 161/500
# 157/157 [==============================] - ETA: 0s - loss: 0.4946 - mae: 0.5255
# Epoch 00161: loss improved from 0.49518 to 0.49464, saving model to ConvLSTM2D_model.h5
# ...
# 157/157 [==============================] - ETA: 0s - loss: 0.3069 - mae: 0.4201
# Epoch 00444: loss did not improve from 0.30468
# 157/157 [==============================] - 23s 147ms/step - loss: 0.3069 - mae: 0.4201 - val_loss: 1.4635 - val_mae: 0.8142
# Epoch 445/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3065 - mae: 0.4190
# Epoch 00445: loss did not improve from 0.30468
# 157/157 [==============================] - 23s 146ms/step - loss: 0.3065 - mae: 0.4190 - val_loss: 1.4634 - val_mae: 0.8143
# Epoch 446/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3055 - mae: 0.4188
# Epoch 00446: loss did not improve from 0.30468
# 157/157 [==============================] - 23s 147ms/step - loss: 0.3055 - mae: 0.4188 - val_loss: 1.4594 - val_mae: 0.8134
# Epoch 447/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3037 - mae: 0.4179
# Epoch 00447: loss improved from 0.30468 to 0.30372, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.3037 - mae: 0.4179 - val_loss: 1.4570 - val_mae: 0.8132
# Epoch 448/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3050 - mae: 0.4193
# Epoch 00448: loss did not improve from 0.30372
# 157/157 [==============================] - 23s 146ms/step - loss: 0.3050 - mae: 0.4193 - val_loss: 1.4606 - val_mae: 0.8140
# Epoch 449/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3041 - mae: 0.4179
# Epoch 00449: loss did not improve from 0.30372
# 157/157 [==============================] - 23s 146ms/step - loss: 0.3041 - mae: 0.4179 - val_loss: 1.4570 - val_mae: 0.8130
# Epoch 450/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3056 - mae: 0.4190
# Epoch 00450: loss did not improve from 0.30372
# 157/157 [==============================] - 23s 147ms/step - loss: 0.3056 - mae: 0.4190 - val_loss: 1.4585 - val_mae: 0.8134
# Epoch 451/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3009 - mae: 0.4163
# Epoch 00451: loss improved from 0.30372 to 0.30087, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.3009 - mae: 0.4163 - val_loss: 1.4614 - val_mae: 0.8145
# Epoch 452/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3004 - mae: 0.4159
# Epoch 00452: loss improved from 0.30087 to 0.30036, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.3004 - mae: 0.4159 - val_loss: 1.4652 - val_mae: 0.8150
# Epoch 453/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2999 - mae: 0.4160
# Epoch 00453: loss improved from 0.30036 to 0.29988, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2999 - mae: 0.4160 - val_loss: 1.4594 - val_mae: 0.8136
# Epoch 454/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3011 - mae: 0.4163
# Epoch 00454: loss did not improve from 0.29988
# 157/157 [==============================] - 23s 146ms/step - loss: 0.3011 - mae: 0.4163 - val_loss: 1.4653 - val_mae: 0.8156
# Epoch 455/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3003 - mae: 0.4155
# Epoch 00455: loss did not improve from 0.29988
# 157/157 [==============================] - 23s 147ms/step - loss: 0.3003 - mae: 0.4155 - val_loss: 1.4639 - val_mae: 0.8147
# Epoch 456/500
# 157/157 [==============================] - ETA: 0s - loss: 0.3020 - mae: 0.4160
# Epoch 00456: loss did not improve from 0.29988
# 157/157 [==============================] - 23s 146ms/step - loss: 0.3020 - mae: 0.4160 - val_loss: 1.4628 - val_mae: 0.8141
# Epoch 457/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2994 - mae: 0.4149
# Epoch 00457: loss improved from 0.29988 to 0.29944, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 148ms/step - loss: 0.2994 - mae: 0.4149 - val_loss: 1.4609 - val_mae: 0.8138
# Epoch 458/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2984 - mae: 0.4154
# Epoch 00458: loss improved from 0.29944 to 0.29838, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2984 - mae: 0.4154 - val_loss: 1.4641 - val_mae: 0.8147
# Epoch 459/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2999 - mae: 0.4155
# Epoch 00459: loss did not improve from 0.29838
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2999 - mae: 0.4155 - val_loss: 1.4669 - val_mae: 0.8150
# Epoch 460/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2997 - mae: 0.4154
# Epoch 00460: loss did not improve from 0.29838
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2997 - mae: 0.4154 - val_loss: 1.4620 - val_mae: 0.8141
# Epoch 461/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2995 - mae: 0.4151
# Epoch 00461: loss did not improve from 0.29838
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2995 - mae: 0.4151 - val_loss: 1.4643 - val_mae: 0.8147
# Epoch 462/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2970 - mae: 0.4144
# Epoch 00462: loss improved from 0.29838 to 0.29699, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2970 - mae: 0.4144 - val_loss: 1.4651 - val_mae: 0.8148
# Epoch 463/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2983 - mae: 0.4147
# Epoch 00463: loss did not improve from 0.29699
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2983 - mae: 0.4147 - val_loss: 1.4611 - val_mae: 0.8143
# Epoch 464/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2971 - mae: 0.4130
# Epoch 00464: loss did not improve from 0.29699
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2971 - mae: 0.4130 - val_loss: 1.4653 - val_mae: 0.8150
# Epoch 465/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2964 - mae: 0.4133
# Epoch 00465: loss improved from 0.29699 to 0.29639, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2964 - mae: 0.4133 - val_loss: 1.4618 - val_mae: 0.8146
# Epoch 466/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2975 - mae: 0.4141
# Epoch 00466: loss did not improve from 0.29639
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2975 - mae: 0.4141 - val_loss: 1.4636 - val_mae: 0.8145
# Epoch 467/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2946 - mae: 0.4119
# Epoch 00467: loss improved from 0.29639 to 0.29458, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2946 - mae: 0.4119 - val_loss: 1.4591 - val_mae: 0.8135
# Epoch 468/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2959 - mae: 0.4129
# Epoch 00468: loss did not improve from 0.29458
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2959 - mae: 0.4129 - val_loss: 1.4614 - val_mae: 0.8143
# Epoch 469/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2945 - mae: 0.4123
# Epoch 00469: loss improved from 0.29458 to 0.29445, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2945 - mae: 0.4123 - val_loss: 1.4599 - val_mae: 0.8137
# Epoch 470/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2952 - mae: 0.4114
# Epoch 00470: loss did not improve from 0.29445
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2952 - mae: 0.4114 - val_loss: 1.4598 - val_mae: 0.8138
# Epoch 471/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2957 - mae: 0.4126
# Epoch 00471: loss did not improve from 0.29445
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2957 - mae: 0.4126 - val_loss: 1.4628 - val_mae: 0.8150
# Epoch 472/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2945 - mae: 0.4116
# Epoch 00472: loss did not improve from 0.29445
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2945 - mae: 0.4116 - val_loss: 1.4624 - val_mae: 0.8144
# Epoch 473/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2931 - mae: 0.4115
# Epoch 00473: loss improved from 0.29445 to 0.29311, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2931 - mae: 0.4115 - val_loss: 1.4611 - val_mae: 0.8147
# Epoch 474/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2951 - mae: 0.4121
# Epoch 00474: loss did not improve from 0.29311
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2951 - mae: 0.4121 - val_loss: 1.4663 - val_mae: 0.8159
# Epoch 475/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2939 - mae: 0.4111
# Epoch 00475: loss did not improve from 0.29311
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2939 - mae: 0.4111 - val_loss: 1.4624 - val_mae: 0.8149
# Epoch 476/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2919 - mae: 0.4106
# Epoch 00476: loss improved from 0.29311 to 0.29190, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2919 - mae: 0.4106 - val_loss: 1.4615 - val_mae: 0.8144
# Epoch 477/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2932 - mae: 0.4103
# Epoch 00477: loss did not improve from 0.29190
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2932 - mae: 0.4103 - val_loss: 1.4623 - val_mae: 0.8150
# Epoch 478/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2933 - mae: 0.4102
# Epoch 00478: loss did not improve from 0.29190
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2933 - mae: 0.4102 - val_loss: 1.4654 - val_mae: 0.8158
# Epoch 479/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2906 - mae: 0.4095
# Epoch 00479: loss improved from 0.29190 to 0.29055, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2906 - mae: 0.4095 - val_loss: 1.4643 - val_mae: 0.8152
# Epoch 480/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2903 - mae: 0.4089
# Epoch 00480: loss improved from 0.29055 to 0.29033, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2903 - mae: 0.4089 - val_loss: 1.4652 - val_mae: 0.8154
# Epoch 481/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2899 - mae: 0.4085
# Epoch 00481: loss improved from 0.29033 to 0.28994, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2899 - mae: 0.4085 - val_loss: 1.4624 - val_mae: 0.8149
# Epoch 482/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2913 - mae: 0.4098
# Epoch 00482: loss did not improve from 0.28994
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2913 - mae: 0.4098 - val_loss: 1.4663 - val_mae: 0.8157
# Epoch 483/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2908 - mae: 0.4087
# Epoch 00483: loss did not improve from 0.28994
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2908 - mae: 0.4087 - val_loss: 1.4650 - val_mae: 0.8154
# Epoch 484/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2892 - mae: 0.4079
# Epoch 00484: loss improved from 0.28994 to 0.28919, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2892 - mae: 0.4079 - val_loss: 1.4628 - val_mae: 0.8146
# Epoch 485/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2891 - mae: 0.4083
# Epoch 00485: loss improved from 0.28919 to 0.28913, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2891 - mae: 0.4083 - val_loss: 1.4652 - val_mae: 0.8156
# Epoch 486/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2886 - mae: 0.4074
# Epoch 00486: loss improved from 0.28913 to 0.28864, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2886 - mae: 0.4074 - val_loss: 1.4621 - val_mae: 0.8147
# Epoch 487/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2880 - mae: 0.4075
# Epoch 00487: loss improved from 0.28864 to 0.28801, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2880 - mae: 0.4075 - val_loss: 1.4624 - val_mae: 0.8146
# Epoch 488/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2896 - mae: 0.4074
# Epoch 00488: loss did not improve from 0.28801
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2896 - mae: 0.4074 - val_loss: 1.4655 - val_mae: 0.8152
# Epoch 489/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2893 - mae: 0.4073
# Epoch 00489: loss did not improve from 0.28801
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2893 - mae: 0.4073 - val_loss: 1.4651 - val_mae: 0.8155
# Epoch 490/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2888 - mae: 0.4076
# Epoch 00490: loss did not improve from 0.28801
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2888 - mae: 0.4076 - val_loss: 1.4666 - val_mae: 0.8153
# Epoch 491/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2867 - mae: 0.4065
# Epoch 00491: loss improved from 0.28801 to 0.28669, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2867 - mae: 0.4065 - val_loss: 1.4651 - val_mae: 0.8156
# Epoch 492/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2870 - mae: 0.4064
# Epoch 00492: loss did not improve from 0.28669
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2870 - mae: 0.4064 - val_loss: 1.4651 - val_mae: 0.8155
# Epoch 493/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2857 - mae: 0.4053
# Epoch 00493: loss improved from 0.28669 to 0.28567, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2857 - mae: 0.4053 - val_loss: 1.4667 - val_mae: 0.8158
# Epoch 494/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2860 - mae: 0.4061
# Epoch 00494: loss did not improve from 0.28567
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2860 - mae: 0.4061 - val_loss: 1.4633 - val_mae: 0.8152
# Epoch 495/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2838 - mae: 0.4048
# Epoch 00495: loss improved from 0.28567 to 0.28377, saving model to ConvLSTM2D_model.h5
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2838 - mae: 0.4048 - val_loss: 1.4650 - val_mae: 0.8156
# Epoch 496/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2851 - mae: 0.4054
# Epoch 00496: loss did not improve from 0.28377
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2851 - mae: 0.4054 - val_loss: 1.4652 - val_mae: 0.8153
# Epoch 497/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2854 - mae: 0.4056
# Epoch 00497: loss did not improve from 0.28377
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2854 - mae: 0.4056 - val_loss: 1.4671 - val_mae: 0.8154
# Epoch 498/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2851 - mae: 0.4052
# Epoch 00498: loss did not improve from 0.28377
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2851 - mae: 0.4052 - val_loss: 1.4664 - val_mae: 0.8158
# Epoch 499/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2846 - mae: 0.4045
# Epoch 00499: loss did not improve from 0.28377
# 157/157 [==============================] - 23s 146ms/step - loss: 0.2846 - mae: 0.4045 - val_loss: 1.4657 - val_mae: 0.8156
# Epoch 500/500
# 157/157 [==============================] - ETA: 0s - loss: 0.2848 - mae: 0.4043
# Epoch 00500: loss did not improve from 0.28377
# 157/157 [==============================] - 23s 147ms/step - loss: 0.2848 - mae: 0.4043 - val_loss: 1.4646 - val_mae: 0.8152

# %% [markdown]
# ## Test the model

# %%
X_test_scaled = pipeline_x_loaded.transform(X_test)
y_test_scaled = pipeline_y_loaded.transform(y_test.values.reshape((-1,1)))

X_test_scaled.astype('float32')
y_test_scaled.astype('float32')

# Concat features and target
test_dataset = np.hstack((X_test_scaled, y_test_scaled))
# convert into input/output
X_test_split, y_test_split = split_sequences(test_dataset, n_steps_split)
y_test_split = np.reshape(y_test_split, (-1, 1))
# the dataset knows the number of features, e.g. 2
n_features = X_test_split.shape[2]

X_test_split = X_test_split.reshape((X_test_split.shape[0], n_seq, rows, n_steps, n_features))

# Load model
model = load_model('ConvLSTM2D_model.h5')
yhat = model.predict(X_test_split)
yhat = yhat.reshape((-1, 1)) # For TimeDistributed
predicted = pipeline_y_loaded.inverse_transform(yhat)

evaluation = model.evaluate(X_test_split, y_test_split)
print('Model evaluation: ', evaluation)
# Out:
# 1793/1793 [==============================] - 18s 10ms/step - loss: 0.7971 - mean_absolute_error: 0.6527
# Model evaluation:  [0.7970717549324036, 0.6526634097099304]

# %% [markdown]
# #### Predictions

# %%
# Predictions table
df_predicted = pd.DataFrame()
df_predicted['short_result'] = y_test.iloc[n_steps_split -1:]
df_predicted['predictions'] = predicted
#df_predicted = round(df_predicted,1)
print(df_predicted.tail(20))
# Out:
#             short_result  predictions
# date
# 2020-08-03          -8.0    -1.967878
# 2020-08-04         -10.0    -3.284093
# 2020-08-05         -11.0    -3.787450
# 2020-08-06          -9.0    -3.950069
# 2020-08-07          -9.0    -3.396972
# 2020-08-10         -11.0    -3.598960
# 2020-08-11         -13.0    -3.343391
# 2020-08-12         -12.0    -2.993070
# 2020-08-13          -9.0    -2.220551
# 2020-08-14         -10.0    -2.327138
# 2020-08-17          -8.0    -1.693337
# 2020-08-18          -7.0    -2.066626
# 2020-08-19          -7.0    -2.356326
# 2020-08-20          -5.0    -2.141423
# 2020-08-21          -4.0    -0.924281
# 2020-08-24          -6.0    -0.520626
# 2020-08-25          -2.0     1.307150
# 2020-08-26           1.0     2.558797
# 2020-08-27           2.0     2.994626
# 2020-08-28           0.0     2.505793

# %%
# Plot the predictions
plt.plot(df_predicted.iloc[-150:]);

# %%
# Analyse the values
df_predicted.describe().T
# Out:
#                 count      mean       std  ...       50%       75%       max
# short_result  57375.0  0.258806  6.109247  ...  0.000000  3.000000  58.00000
# predictions   57375.0  0.473673  3.679986  ...  0.434011  2.539183  49.09626
#
# [2 rows x 8 columns]

# %%
# Metrics
mse = round(mean_squared_error(y_test.iloc[n_steps_split -1:],predicted), 2)
rmse = math.sqrt(mean_squared_error(y_test.iloc[n_steps_split -1:],predicted))
mae = round(mean_absolute_error(y_test.iloc[n_steps_split -1:],predicted), 2)
r2 = round(r2_score(y_test.iloc[n_steps_split -1:],predicted), 2) 
print('mse: ', mse)
print('rmse: ', rmse)
print('mae: ', mae)
print('r2: ', r2)
# Out:
# mse:  45.82
# rmse:  6.769312234684703
# mae:  4.95
# r2:  -0.23
